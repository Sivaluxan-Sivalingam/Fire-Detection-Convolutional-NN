# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Define dataset path and categories
DATADIR = '/Users/sivaluxan/Documents/AI/MLP/Project/FireNet-LightWeight-Network-for-Fire-Detection/Training Dataset'
CATEGORIES = ['Fire', 'NoFire']
IMG_SIZE = 64

def create_training_data():
    training_data = []
    for category in CATEGORIES:  
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception:
                pass
    return training_data

# Load and preprocess data
training_data = create_training_data()
X, Y = [], []
for features, label in training_data:
    X.append(features)
    Y.append(label)

# Normalize the data
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255.0
Y = np.array(Y)
# Out:
# 100%|██████████████████████████████████████| 1124/1124 [00:02<00:00, 405.16it/s]
# 100%|██████████████████████████████████████| 1301/1301 [00:06<00:00, 205.84it/s]

# %%
# Split dataset into train and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Apply data augmentation only to training data
train_datagen = ImageDataGenerator(
    rotation_range=20,  # Reduced from 30
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    brightness_range=[0.9, 1.1],  # More stable range
    zoom_range=0.2,  # Reduced from 0.3
    fill_mode='nearest'
)


val_datagen = ImageDataGenerator()  # No augmentation for validation

# Create generators
train_generator = train_datagen.flow(X_train, Y_train, batch_size=32, shuffle=True)
val_generator = val_datagen.flow(X_val, Y_val, batch_size=32)

# %%
# Define the CNN model
model = Sequential()
from tensorflow.keras.layers import Activation


model.add(Conv2D(32, (3,3), padding='same', input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))  # Reduced from 0.4

model.add(Conv2D(64, (3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))  # Reduced from 0.3

# ✨ Extra Conv Layer for better feature extraction
model.add(Conv2D(128, (3,3), padding='same'))  
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(2, activation='softmax'))

# %%
# Compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),  # Increased from 0.0005
              metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
import numpy as np

X = np.array(X)
Y = np.array(Y)

history = model.fit(X, Y, batch_size=32, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 4s 56ms/step - loss: 0.4191 - accuracy: 0.8237 - val_loss: 2.2409 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.3312 - accuracy: 0.8538 - val_loss: 2.3991 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.2732 - accuracy: 0.8886 - val_loss: 2.5685 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 53/53 [==============================] - 3s 59ms/step - loss: 0.2094 - accuracy: 0.9198 - val_loss: 3.2372 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.1946 - accuracy: 0.9186 - val_loss: 3.6351 - val_accuracy: 0.0014
# Epoch 6/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1850 - accuracy: 0.9310 - val_loss: 4.6507 - val_accuracy: 0.0014
# Epoch 7/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1533 - accuracy: 0.9393 - val_loss: 2.0507 - val_accuracy: 0.2036
# Epoch 8/100
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1362 - accuracy: 0.9481 - val_loss: 1.0681 - val_accuracy: 0.5640
# Epoch 9/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.1260 - accuracy: 0.9564 - val_loss: 1.7369 - val_accuracy: 0.4154
# Epoch 10/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1081 - accuracy: 0.9629 - val_loss: 0.4373 - val_accuracy: 0.8281
# Epoch 11/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0679 - accuracy: 0.9788 - val_loss: 0.7080 - val_accuracy: 0.7166
# Epoch 12/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0717 - accuracy: 0.9729 - val_loss: 1.1228 - val_accuracy: 0.5873
# Epoch 13/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0537 - accuracy: 0.9853 - val_loss: 0.2387 - val_accuracy: 0.9202
# Epoch 14/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0600 - accuracy: 0.9847 - val_loss: 1.5092 - val_accuracy: 0.5942
# Epoch 15/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0869 - accuracy: 0.9705 - val_loss: 1.0220 - val_accuracy: 0.7084
# Epoch 16/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0671 - accuracy: 0.9752 - val_loss: 0.1950 - val_accuracy: 0.9243
# Epoch 17/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0550 - accuracy: 0.9835 - val_loss: 0.7888 - val_accuracy: 0.7854
# Epoch 18/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0414 - accuracy: 0.9853 - val_loss: 0.7039 - val_accuracy: 0.8074
# Epoch 19/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0406 - accuracy: 0.9876 - val_loss: 0.8115 - val_accuracy: 0.7772
# Epoch 20/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0219 - accuracy: 0.9941 - val_loss: 0.6946 - val_accuracy: 0.8143
# Epoch 21/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0308 - accuracy: 0.9912 - val_loss: 0.7068 - val_accuracy: 0.8033
# Epoch 22/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.8216 - val_accuracy: 0.7992
# Epoch 23/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0363 - accuracy: 0.9894 - val_loss: 0.8390 - val_accuracy: 0.7510
# Epoch 24/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0322 - accuracy: 0.9888 - val_loss: 0.3737 - val_accuracy: 0.9037
# Epoch 25/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0370 - accuracy: 0.9906 - val_loss: 0.5037 - val_accuracy: 0.8693
# Epoch 26/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0407 - accuracy: 0.9882 - val_loss: 1.4756 - val_accuracy: 0.6561
# Epoch 27/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 0.6425 - val_accuracy: 0.8363
# Epoch 28/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 1.2496 - val_accuracy: 0.7827
# Epoch 29/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0304 - accuracy: 0.9882 - val_loss: 0.7403 - val_accuracy: 0.8184
# Epoch 30/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0305 - accuracy: 0.9894 - val_loss: 0.7259 - val_accuracy: 0.8556
# Epoch 31/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0300 - accuracy: 0.9912 - val_loss: 1.0814 - val_accuracy: 0.7607
# Epoch 32/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0279 - accuracy: 0.9888 - val_loss: 1.1434 - val_accuracy: 0.7593
# Epoch 33/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0402 - accuracy: 0.9835 - val_loss: 1.0859 - val_accuracy: 0.7937
# Epoch 34/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0269 - accuracy: 0.9917 - val_loss: 0.3516 - val_accuracy: 0.8982
# Epoch 35/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0134 - accuracy: 0.9965 - val_loss: 0.7291 - val_accuracy: 0.8171
# Epoch 36/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.3434 - val_accuracy: 0.9078
# Epoch 37/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0223 - accuracy: 0.9912 - val_loss: 0.8946 - val_accuracy: 0.8006
# Epoch 38/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.6214 - val_accuracy: 0.8707
# Epoch 39/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.6584 - val_accuracy: 0.8707
# Epoch 40/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0157 - accuracy: 0.9935 - val_loss: 0.9677 - val_accuracy: 0.7937
# Epoch 41/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0118 - accuracy: 0.9982 - val_loss: 0.8945 - val_accuracy: 0.8308
# Epoch 42/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 1.0403 - val_accuracy: 0.7840
# Epoch 43/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0171 - accuracy: 0.9965 - val_loss: 0.6409 - val_accuracy: 0.8652
# Epoch 44/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0243 - accuracy: 0.9906 - val_loss: 1.4062 - val_accuracy: 0.7442
# Epoch 45/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 1.1063 - val_accuracy: 0.7428
# Epoch 46/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.4069 - val_accuracy: 0.8955
# Epoch 47/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0400 - accuracy: 0.9847 - val_loss: 0.4519 - val_accuracy: 0.8748
# Epoch 48/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.9539 - val_accuracy: 0.8226
# Epoch 49/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.3808 - val_accuracy: 0.9092
# Epoch 50/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0230 - accuracy: 0.9941 - val_loss: 0.7712 - val_accuracy: 0.8322
# Epoch 51/100
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.8462 - val_accuracy: 0.8501
# Epoch 52/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 1.0201 - val_accuracy: 0.7772
# Epoch 53/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.5469 - val_accuracy: 0.8748
# Epoch 54/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.6057 - val_accuracy: 0.8569
# Epoch 55/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.7418 - val_accuracy: 0.8212
# Epoch 56/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.4787 - val_accuracy: 0.8735
# Epoch 57/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0180 - accuracy: 0.9929 - val_loss: 1.6531 - val_accuracy: 0.7139
# Epoch 58/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0470 - accuracy: 0.9823 - val_loss: 0.5342 - val_accuracy: 0.8803
# Epoch 59/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0436 - accuracy: 0.9876 - val_loss: 1.4434 - val_accuracy: 0.7455
# Epoch 60/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0186 - accuracy: 0.9923 - val_loss: 0.9398 - val_accuracy: 0.8281
# Epoch 61/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 0.5491 - val_accuracy: 0.8913
# Epoch 62/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.6492 - val_accuracy: 0.8735
# Epoch 63/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.5597 - val_accuracy: 0.8735
# Epoch 64/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.7199 - val_accuracy: 0.8624
# Epoch 65/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.6432 - val_accuracy: 0.8693
# Epoch 66/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.8704 - val_accuracy: 0.8129
# Epoch 67/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.6530 - val_accuracy: 0.8611
# Epoch 68/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.6042 - val_accuracy: 0.8748
# Epoch 69/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.5729 - val_accuracy: 0.8776
# Epoch 70/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.6184 - val_accuracy: 0.8707
# Epoch 71/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.5675 - val_accuracy: 0.8817
# Epoch 72/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.5473 - val_accuracy: 0.8762
# Epoch 73/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0308 - accuracy: 0.9906 - val_loss: 1.2450 - val_accuracy: 0.8267
# Epoch 74/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.5251 - val_accuracy: 0.8927
# Epoch 75/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.6530 - val_accuracy: 0.8858
# Epoch 76/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.5830 - val_accuracy: 0.8858
# Epoch 77/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 0.7279 - val_accuracy: 0.8721
# Epoch 78/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.8139 - val_accuracy: 0.8308
# Epoch 79/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 0.5088 - val_accuracy: 0.8817
# Epoch 80/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0150 - accuracy: 0.9947 - val_loss: 0.9988 - val_accuracy: 0.8404
# Epoch 81/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0269 - accuracy: 0.9876 - val_loss: 0.8948 - val_accuracy: 0.8721
# Epoch 82/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0252 - accuracy: 0.9900 - val_loss: 0.5809 - val_accuracy: 0.8913
# Epoch 83/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.9613 - val_accuracy: 0.8171
# Epoch 84/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 1.2483 - val_accuracy: 0.7400
# Epoch 85/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 1.4476 - val_accuracy: 0.7524
# Epoch 86/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0128 - accuracy: 0.9947 - val_loss: 0.7544 - val_accuracy: 0.8652
# Epoch 87/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 0.7240 - val_accuracy: 0.8583
# Epoch 88/100
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.7157 - val_accuracy: 0.8624
# Epoch 89/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.7235 - val_accuracy: 0.8707
# Epoch 90/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0180 - accuracy: 0.9923 - val_loss: 0.6732 - val_accuracy: 0.8913
# Epoch 91/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0257 - accuracy: 0.9906 - val_loss: 1.0116 - val_accuracy: 0.8322
# Epoch 92/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0237 - accuracy: 0.9900 - val_loss: 0.8192 - val_accuracy: 0.8556
# Epoch 93/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 1.8703 - val_accuracy: 0.7689
# Epoch 94/100
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.8643 - val_accuracy: 0.8363
# Epoch 95/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.9615 - val_accuracy: 0.8253
# Epoch 96/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.9247 - val_accuracy: 0.8308
# Epoch 97/100
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.5563 - val_accuracy: 0.8845
# Epoch 98/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0053 - accuracy: 0.9976 - val_loss: 0.5553 - val_accuracy: 0.8872
# Epoch 99/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.6885 - val_accuracy: 0.8803
# Epoch 100/100
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 1.1714 - val_accuracy: 0.7978

# %%
# Save the trained model
model.save('/Users/sivaluxan/Documents/AI/MLP/Project/FireNet-LightWeight-Network-for-Fire-Detection/Trained_Model_FIreNet/Fire-64x64-color-v8.0-optimized-v1.h5')
# Out:
# /Users/sivaluxan/opt/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Plot training history
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Print final accuracy
print(f"Final Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
# Out:
# Final Training Accuracy: 0.9994
# Final Validation Accuracy: 0.7978
